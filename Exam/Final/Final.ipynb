# %% [markdown]
# ## 力学基础概念
# 杨氏模量 E (GPa):
# $$ E = \frac{\sigma}{\varepsilon} = \frac{F \cdot L_0}{A \cdot \Delta L}$$
#
# 其中，σ 是应力，ε 是应变
# E 越大，材料越硬
#
#
# ---
#
# 应力 stress σ (GPA):
# $$ \sigma = \frac{F}{A} $$
#
# 应变 strain ε (no unit):
# $$ \varepsilon = \frac{\Delta L}{L_0} $$
#
# ---
#
# 屈服应力 Yeild Stress
